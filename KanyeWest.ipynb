# %%
from hip_hop_web.Artist import Artist
import lyricsgenius
import os

# %%
genius_token = os.environ.get('GENIUS_TOKEN')
genius = lyricsgenius.Genius(genius_token)
kanye = Artist("Kanye West", genius)

# %%
kanye.create_graph_bfs()
# Out:
# Searching for songs by Kanye West...
#
# Song 1: "Mercy"
# Song 2: "Father Stretch My Hands, Pt. 1"
# Song 3: "Monster"
# Song 4: "Ultralight Beam"
# Song 5: "Bound 2"
# Song 6: "New Slaves"
# Song 7: "Blood on the Leaves"
# Song 8: "Black Skinhead"
# Song 9: "Runaway"
# Song 10: "All Mine"
# Song 11: "No More Parties In LA"
# Song 12: "Famous"
# Song 13: "POWER"
# Song 14: "Real Friends"
# Song 15: "Wolves"
# Song 16: "I Love Kanye"
# Song 17: "Ghost Town"
# Song 18: "Gold Digger"
# Song 19: "Pt. 2"
# Song 20: "Can’t Tell Me Nothing"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# {'weight': 2}
# {'weight': 2}
# {'weight': 2}
# {'weight': 2}
# {'weight': 2}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 3}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 4}
# {'weight': 1}
# {'weight': 1}
# {'weight': 2}
# {'weight': 1}
# {'weight': 1}
# {'weight': 2}
# {'weight': 1}
# {'weight': 1}
# {'weight': 2}
# {'weight': 5}
# {'weight': 2}
# {'weight': 3}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 3}
# {'weight': 6}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 2}
# {'weight': 4}
# {'weight': 4}
# {'weight': 7}
# {'weight': 1}
# {'weight': 1}
# {'weight': 5}
# {'weight': 1}
# {'weight': 1}
# {'weight': 8}
# {'weight': 1}
# {'weight': 9}
# {'weight': 3}
# {'weight': 10}
# {'weight': 1}
# {'weight': 1}
# {'weight': 11}
# {'weight': 6}
# {'weight': 12}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 7}
# {'weight': 1}
# {'weight': 2}
# {'weight': 5}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 13}
# {'weight': 14}
# {'weight': 1}
# {'weight': 1}
# {'weight': 8}
# {'weight': 6}
# {'weight': 2}
# {'weight': 1}
# {'weight': 1}
# {'weight': 15}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 1}
# {'weight': 9}
# {'weight': 3}
# {'weight': 7}
# {'weight': 1}
# {'weight': 1}
# {'weight': 2}
# {'weight': 16}
# {'weight': 17}
# {'weight': 2}
# {'weight': 1}
# {'weight': 10}
# {'weight': 8}
# {'weight': 1}
# {'weight': 18}
# {'weight': 19}
# {'weight': 1}
# {'weight': 1}
# {'weight': 2}
# {'weight': 4}
# {'weight': 1}
# {'weight': 1}
# {'weight': 20}
# {'weight': 3}
# {'weight': 1}
# {'weight': 21}
# Searching for songs by Pusha T...
#
# Song 1: "The Story of Adidon"
# Song 2: "Nosetalgia"
# Song 3: "Infrared"
# Song 4: "Exodus 23:1"
# Song 5: "Sweet Serenade"
# Song 6: "What Would Meek Do?"
# Song 7: "Numbers on the Boards"
# Song 8: "Drug Dealers Anonymous"
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:1371, in HTTPConnection.getresponse(self)
#    1370 try:
# -> 1371     response.begin()
#    1372 except ConnectionError:
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:319, in HTTPResponse.begin(self)
#     318 while True:
# --> 319     version, status, reason = self._read_status()
#     320     if status != CONTINUE:
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/http/client.py:280, in HTTPResponse._read_status(self)
#     279 def _read_status(self):
# --> 280     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281     if len(line) > _MAXLINE:
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File /opt/homebrew/Cellar/python@3.9/3.9.7_1/Frameworks/Python.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/urllib3/connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/urllib3/util/retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/urllib3/packages/six.py:770, in reraise(tp, value, tb)
#     769         raise value.with_traceback(tb)
# --> 770     raise value
#     771 finally:
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/urllib3/connectionpool.py:451, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     452     raise
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/urllib3/connectionpool.py:340, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     339 if isinstance(err, SocketTimeout):
# --> 340     raise ReadTimeoutError(
#     341         self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     342     )
#     344 # See the above comment about EAGAIN in Python 3. In Python 2 we have
#     345 # to specifically catch it and throw the timeout error
#
# ReadTimeoutError: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/lyricsgenius/api/base.py:75, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      74 try:
# ---> 75     response = self._session.request(method, uri,
#      76                                      timeout=self.timeout,
#      77                                      params=params_,
#      78                                      headers=header,
#      79                                      **kwargs)
#      80     response.raise_for_status()
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/requests/adapters.py:532, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     531 elif isinstance(e, ReadTimeoutError):
# --> 532     raise ReadTimeout(e, request=request)
#     533 elif isinstance(e, _InvalidHeader):
#
# ReadTimeout: HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)
#
# During handling of the above exception, another exception occurred:
#
# Timeout                                   Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 kanye.create_graph_bfs()
#
# File ~/code/Hip-Hop-Web/hip_hop_web/Artist.py:30, in Artist.create_graph_bfs(self, artist_limit, song_limit)
#      28 current_artist = artist_queue.get()
#      29 visited.add(current_artist)
# ---> 30 artist = self.__genius.search_artist(current_artist, max_songs=song_limit, sort='popularity')
#      31 # Get artists associated with current artist
#      32 for song_object in artist.songs:
#      33   # Do not want to repeat songs, waste of processing
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/lyricsgenius/genius.py:564, in Genius.search_artist(self, artist_name, max_songs, sort, per_page, get_full_info, allow_name_change, artist_id, include_features)
#     562 # Create the Song object from lyrics and metadata
#     563 if song_info['lyrics_state'] == 'complete':
# --> 564     lyrics = self.lyrics(song_url=song_info['url'])
#     565 else:
#     566     lyrics = ""
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/lyricsgenius/genius.py:132, in Genius.lyrics(self, song_id, song_url, remove_section_headers)
#     128     path = self.song(song_id)['song']['path'][1:]
#     130 # Scrape the song lyrics from the HTML
#     131 html = BeautifulSoup(
# --> 132     self._make_request(path, web=True).replace('<br/>', '\n'),
#     133     "html.parser"
#     134 )
#     136 # Determine the class of the div
#     137 div = html.find("div", class_=re.compile("^lyrics$|Lyrics__Root"))
#
# File ~/.virtualenvs/hip-hop-web/lib/python3.9/site-packages/lyricsgenius/api/base.py:84, in Sender._make_request(self, path, method, params_, public_api, web, **kwargs)
#      82     error = "Request timed out:\n{e}".format(e=e)
#      83     if tries > self.retries:
# ---> 84         raise Timeout(error)
#      85 except HTTPError as e:
#      86     error = get_description(e)
#
# Timeout: Request timed out:
# HTTPSConnectionPool(host='genius.com', port=443): Read timed out. (read timeout=5)

# %%
from pyvis.network import Network
nt = Network('500px', '500px')
nt.from_nx(kanye.graph)
nt.show('nx.html')

# %%
# Out:
# EdgeView([('Kanye West', 'Pusha T'), ('Kanye West', '2 Chainz'), ('Kanye West', 'Big Sean'), ('Kanye West', 'Stepan “Lifted” Taft'), ('Kanye West', 'Kanye West'), ('Kanye West', 'MIKE DEAN'), ('Kanye West', 'Noah Goldstein'), ('Kanye West', 'Allen Ritter'), ('Kanye West', 'DJDS'), ('Kanye West', 'Metro Boomin'), ('Kanye West', 'Kid Cudi'), ('Kanye West', 'Rick Rubin'), ('Kanye West', 'JAY-Z'), ('Kanye West', 'Bon Iver'), ('Kanye West', 'Rick Ross'), ('Kanye West', 'Nicki Minaj'), ('Kanye West', 'Kirk Franklin'), ('Kanye West', 'Swizz Beatz'), ('Kanye West', 'Kelly Price'), ('Kanye West', 'Plain Pat'), ('Kanye West', 'The-Dream'), ('Kanye West', 'Chance the Rapper'), ('Kanye West', 'Che Pope'), ('Kanye West', 'No I.D.'), ('Kanye West', 'Eric Danchild'), ('Kanye West', 'Ben Bronfman'), ('Kanye West', 'SAK PASE'), ('Kanye West', 'Travis Scott'), ('Kanye West', 'Carlos “6 July” Broady'), ('Kanye West', 'TNGHT'), ('Kanye West', '88-Keys'), ('Kanye West', 'Arca'), ('Kanye West', 'Daft Punk'), ('Kanye West', 'ROBOTSCOTT'), ('Kanye West', 'Francis and the Lights'), ('Kanye West', 'Kendrick Lamar'), ('Kanye West', 'Madlib'), ('Kanye West', 'Kuk Harrell'), ('Kanye West', 'Charlie Heat'), ('Kanye West', 'Havoc'), ('Kanye West', 'Rihanna'), ('Kanye West', 'Andrew Dawson'), ('Kanye West', 'Hudson Mohawke'), ('Kanye West', 'S1'), ('Kanye West', 'Ty Dolla $ign'), ('Kanye West', 'Sevn Thomas'), ('Kanye West', 'Boi-1da'), ('Kanye West', 'Darren King'), ('Kanye West', 'Ging'), ('Kanye West', 'Caroline Shaw'), ('Kanye West', 'Sia'), ('Kanye West', 'VIC MENSA'), ('Kanye West', 'Cashmere Cat'), ('Kanye West', 'Sinjin Hawke'), ('Kanye West', 'PARTYNEXTDOOR'), ('Kanye West', '\u200bbenny blanco'), ('Kanye West', 'Jon Brion'), ('Kanye West', 'Jamie Foxx'), ('Kanye West', 'Desiigner'), ('Kanye West', 'Menace'), ('Kanye West', 'DJ Toomp'), ('Pusha T', 'No I.D.'), ('Pusha T', 'JAY-Z')])
